# %%
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %%
# load in the data 
delay_df = pd.read_csv('Toronto-Subway-Delay-Jan-2014-Jun-2021.csv')
code_df = pd.read_csv('Toronto-Subway-Delay-Codes.csv')

# %% [markdown]
# The goal of analyzing this data set is to determine whether we can predict your subway delay times

# %% [markdown]
# # DATA CLEANING AND WRANGLING

# %%
# view data set
delay_df.head()
# Out:
#          Date   Time        Day                Station   Code  Min Delay  \
# 0  2014/01/01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1  2014/01/01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 2  2014/01/01  02:40  Wednesday       SHEPPARD STATION  MUNCA          0
# 3  2014/01/01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4  2014/01/01  03:20  Wednesday          BLOOR STATION  MUSAN          5
#
#    Min Gap Bound Line  Vehicle
# 0       60     W   BD     5111
# 1        7     W   BD     5001
# 2        0   NaN   YU        0
# 3        8     W   BD     5116
# 4       10     S   YU     5386

# %%
delay_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143917 entries, 0 to 143916
# Data columns (total 10 columns):
# Date         143917 non-null object
# Time         143917 non-null object
# Day          143917 non-null object
# Station      143917 non-null object
# Code         143916 non-null object
# Min Delay    143917 non-null int64
# Min Gap      143917 non-null int64
# Bound        111703 non-null object
# Line         143373 non-null object
# Vehicle      143917 non-null int64
# dtypes: int64(3), object(7)
# memory usage: 11.0+ MB

# %% [markdown]
# Dataset contains date, time and day of the subway delay, station it occurs at, code of the delay, the direction the subway is bound in, the line the subway is on and the vehicle number

# %%
# view codes dataset
code_df.head()
# Out:
#    Code # RMENU CODE Vehicle Type     CODE DESCRIPTION
# 0       1       EUAC          SUB     Air Conditioning
# 1       2       EUAL          SUB  Alternating Current
# 2       3      EUATC          SUB   ATC RC&S Equipment
# 3       4       EUBK          SUB               Brakes
# 4       5       EUBO          SUB                 Body

# %% [markdown]
# Dataset contains codes for delay types, description for what the delay is and the type of vehicle it occured in

# %%
# rename the column in code_df so that merge can be performed
code_df.rename(columns = {'RMENU CODE': "Code"}, inplace = True)

# %%
# merge the df containing delays and code data 

big_df = pd.merge(delay_df, code_df, how = "left", on = "Code")

# %%
# view if merge was done correctly
big_df.head()
# Out:
#          Date   Time        Day                Station   Code  Min Delay  \
# 0  2014/01/01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1  2014/01/01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 2  2014/01/01  02:40  Wednesday       SHEPPARD STATION  MUNCA          0
# 3  2014/01/01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4  2014/01/01  03:20  Wednesday          BLOOR STATION  MUSAN          5
#
#    Min Gap Bound Line  Vehicle  Code # Vehicle Type  \
# 0       60     W   BD     5111    52.0          SUB
# 1        7     W   BD     5001   105.0          SUB
# 2        0   NaN   YU        0     NaN          NaN
# 3        8     W   BD     5116   105.0          SUB
# 4       10     S   YU     5386    53.0          SUB
#
#                               CODE DESCRIPTION
# 0  Priority One - Train in Contact With Person
# 1                            Disorderly Patron
# 2                                          NaN
# 3                            Disorderly Patron
# 4                           Unsanitary Vehicle

# %% [markdown]
# # Dealing with Missing Data

# %%
# look at basic info of data frame
big_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143917 entries, 0 to 143916
# Data columns (total 13 columns):
# Date                143917 non-null object
# Time                143917 non-null object
# Day                 143917 non-null object
# Station             143917 non-null object
# Code                143916 non-null object
# Min Delay           143917 non-null int64
# Min Gap             143917 non-null int64
# Bound               111703 non-null object
# Line                143373 non-null object
# Vehicle             143917 non-null int64
# Code #              140859 non-null float64
# Vehicle Type        140859 non-null object
# CODE DESCRIPTION    140859 non-null object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 15.4+ MB

# %%
# check for nulls in data 
big_df.isnull().sum()
# Out:
# Date                    0
# Time                    0
# Day                     0
# Station                 0
# Code                    1
# Min Delay               0
# Min Gap                 0
# Bound               32214
# Line                  544
# Vehicle                 0
# Code #               3058
# Vehicle Type         3058
# CODE DESCRIPTION     3058
# dtype: int64

# %% [markdown]
# There are nulls present in the Bound column (indicating direction of subway), Line Column, Vechicle type, Code # and Code Description

# %% [markdown]
# View the meaning of the blanks in the dataset

# %%
# Determine the number of missing values 
for col in big_df.columns:
    missing = big_df[col].isna().sum()
    percent = missing / big_df.shape[0] * 100
    print("%s: %.2f%% (%d)" % (col,percent,missing))
# Out:
# Date: 0.00% (0)
# Time: 0.00% (0)
# Day: 0.00% (0)
# Station: 0.00% (0)
# Code: 0.00% (1)
# Min Delay: 0.00% (0)
# Min Gap: 0.00% (0)
# Bound: 22.38% (32214)
# Line: 0.38% (544)
# Vehicle: 0.00% (0)
# Code #: 2.12% (3058)
# Vehicle Type: 2.12% (3058)
# CODE DESCRIPTION: 2.12% (3058)

# %% [markdown]
# As the blanks in Bound consist of 22.38% of the total data, these will be filled in with the mode of the column

# %%
big_df['Bound'] = big_df['Bound'].fillna(value = big_df['Bound'].mode()[0], axis = 0, )

# %% [markdown]
# Seeing as the Line, Code, Vehicle Type and CODE DESCRIPTION columns blanks ony consist of <3% of the total data, these will be dropped

# %%
big_df.dropna(how = "any", inplace = True)

# %%
# check the blanks of the data 
big_df.isnull().sum()
# Out:
# Date                0
# Time                0
# Day                 0
# Station             0
# Code                0
# Min Delay           0
# Min Gap             0
# Bound               0
# Line                0
# Vehicle             0
# Code #              0
# Vehicle Type        0
# CODE DESCRIPTION    0
# dtype: int64

# %% [markdown]
# # Covert Date Times to Pandas Date Time Object

# %%
# set the date column as a datetime object
big_df['Date'] = pd.to_datetime(big_df['Date'])

# %%
# create merged Date Time Column 
big_df['Datetime'] = big_df['Date'] + " " + big_df['Time']

# %%
# plot subway delays throughout time 
big_df['Datetime'] = pd.to_datetime(big_df['Datetime'])

# %%
# import pytz package 
import pytz

# %%
# localize timezone to EST (Toronto Timezone)
# declare eastern time stamp variable to use in for loop 
est = pytz.timezone('Canada/Eastern')

# Apply the EST timezone to all date times in index column 
big_df['Datetime'] = big_df.apply(lambda row: est.localize(row['Datetime']), axis = 1)

# %%
# create hour column which will be used in plots later
big_df['Hour'] = big_df.index.hour

# %%
# create month column which will be used in plots later 
big_df['Month'] = big_df['Datetime'].dt.month

# %%
# make day column a datetime object
big_df['Day'] = big_df['Date'].dt.dayofweek

# %% [markdown]
# # Make sure all data is consistent

# %%
# upper case all data in columns such that its consistent throughout
big_df['CODE DESCRIPTION'] = big_df['CODE DESCRIPTION'].str.upper()

# %%
# Fix title of column names 
big_df.rename(columns = {"CODE DESCRIPTION":"Code Description"}, inplace = True)

# %%
# create another column called "Count" with values of 1 for later data aggregation
big_df['Count'] = 1

# %%
big_df.head()
# Out:
#         Date   Time  Day                Station   Code  Min Delay  Min Gap  \
# 0 2014-01-01  00:21    2  VICTORIA PARK STATION  MUPR1         55       60
# 1 2014-01-01  02:06    2      HIGH PARK STATION   SUDP          3        7
# 2 2014-01-01  03:10    2      LANSDOWNE STATION   SUDP          3        8
# 3 2014-01-01  03:20    2          BLOOR STATION  MUSAN          5       10
# 4 2014-01-01  03:29    2       DUFFERIN STATION  MUPAA          0        0
#
#   Bound Line  Vehicle  Code # Vehicle Type  \
# 0     W   BD     5111    52.0          SUB
# 1     W   BD     5001   105.0          SUB
# 2     W   BD     5116   105.0          SUB
# 3     S   YU     5386    53.0          SUB
# 4     E   BD     5174    48.0          SUB
#
#                                     Code Description  \
# 0        PRIORITY ONE - TRAIN IN CONTACT WITH PERSON
# 1                                  DISORDERLY PATRON
# 2                                  DISORDERLY PATRON
# 3                                 UNSANITARY VEHICLE
# 4  PASSENGER ASSISTANCE ALARM ACTIVATED - NO TROU...
#
#                    Datetime  Hour  Count  Month
# 0 2014-01-01 00:21:00-05:00     0      1      1
# 1 2014-01-01 02:06:00-05:00     2      1      1
# 2 2014-01-01 03:10:00-05:00     3      1      1
# 3 2014-01-01 03:20:00-05:00     3      1      1
# 4 2014-01-01 03:29:00-05:00     3      1      1

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Create a pairwise plot to determine what values are correlated by creating PairWise Plots
plt.figure(figsize = (15,5))
sns.pairplot(big_df)

# %% [markdown]
# What did delays look like throughout the year? What was the impact of lockdown on subway delays?

# %%
#TimeSeries plot of subway delays throughout the years 

plt.figure(figsize = (10,5))
sns.lineplot(x = big_df.set_index("Date").resample("m").sum().index, y = big_df.set_index("Date").resample("m").sum()['Min Delay'], color = "grey")
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Number of Delays", fontsize = 14)
plt.xlim("2015","2021")
plt.title("Examining the Monthly Increase of Subway Delays caused by COVID 2019", fontsize = 14, weight = "bold")
plt.savefig("Monthly Effect of COVID 19")

# %% [markdown]
# Examining the plot above, it appears that there is a greater amount of subway delays due to COVID 19, however average out yearly data to be sure

# %%
#TimeSeries plot of subway delays throughout the years 

plt.figure(figsize = (10,5))
sns.lineplot(x = big_df.set_index("Date").resample("y").sum().index, y = big_df.set_index("Date").resample("y").sum()['Min Delay'], color = "grey")
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Number of Delays", fontsize = 14)
plt.xlim("2015","2021")
plt.title("Examining the Yearly Increase of Subway Delays caused by COVID 2019", fontsize = 14, weight = "bold")
plt.savefig("Yearly Effect of COVID 19")

# %% [markdown]
# Looking at yearly average subway delays, the year of the pandemic, 2020, and 2021 appear higher than the previous year, although not as high as in 2019, could this be because of the pandemic and less staff employed?

# %% [markdown]
# Upon further investigation: The TTC laid of 1200 employees in April 2020 https://www.cbc.ca/news/canada/toronto/ttc-layoffs-1.5542445
# https://globalnews.ca/news/6857983/coronavirus-ttc-layoffs/
#
# All employees who were not able to meet their vaccination status were fired in 2021:
# https://globalnews.ca/news/8269099/ttc-terminate-employees-covid-vaccination-policy/

# %% [markdown]
# Why was there a sudden peak/increase in the number of delays in 2019? Article was found discussing complaining Torontonians on the amount of subway delays experienced this particular year. https://toronto.citynews.ca/2020/01/03/ttc-delays-2019/
# Article sources the amount of delays this year to be predominantly because of signal problems, rail issues, weather-related issues, unauthorized people on track levels, fires and so on.

# %%
# determine the top 10 reasons for subway delays the occured in 2019 
big_df[(big_df['Date'].dt.year == 2019)]['CODE DESCRIPTION'].value_counts().head(10)
# Out:
# Miscellaneous Speed Control                                 1962
# Passenger Assistance Alarm Activated - No Trouble Found     1383
# Operator Overspeeding                                       1370
# Disorderly Patron                                            971
# Injured or ill Customer (On Train) - Medical Aid Refused     669
# Injured or ill Customer (In Station) - Transported           560
# Speed Control Equipment                                      523
# ATC Project                                                  510
# Operator Violated Signal                                     463
# Injured or ill Customer (On Train) - Transported             448
# Name: CODE DESCRIPTION, dtype: int64

# %% [markdown]
# Half of the top 10 reasons for signal delays in 2019 were because of passenger issues. During the pandemic where there were less passengers on board due to the work from home mandate, what were the top 10 reasons for delays then?

# %%
# determine the top 10 reasons for subway delays the occured in 2020 and 2021
big_df[(big_df['Date'].dt.year == 2020) | (big_df['Date'].dt.year == 2021)]['CODE DESCRIPTION'].value_counts().head(10)
# Out:
# Disorderly Patron                                           2048
# Passenger Assistance Alarm Activated - No Trouble Found     1313
# No Operator Immediately Available - Not E.S.A. Related      1281
# Miscellaneous Speed Control                                  913
# Operator Overspeeding                                        655
# Operator Violated Signal                                     594
# ATC Project                                                  593
# Injured or ill Customer (In Station) - Transported           491
# Injured or ill Customer (On Train) - Medical Aid Refused     484
# Unauthorized at Track Level                                  463
# Name: CODE DESCRIPTION, dtype: int64

# %% [markdown]
# Interesting to note that during the pandemic, the top third reason that was not found in the previous year for delays is "No Opereator Immediately Available - Not E.S.A Related" which could be due to the layoff of employees from the corporation
# It is also interesting to note that the #1 reason for delays during the pandemic years are disorderly customers and in the top 10 are unauthorized customers at the track level
# The COVID-19 panemic and recession has adversely affected many people's mental health. During the pandemic,it was discovered that 4 in 10 adults have reported symptoms of anxeity or depressive disorder.
# https://www.kff.org/coronavirus-covid-19/issue-brief/the-implications-of-covid-19-for-mental-health-and-substance-use/

# %% [markdown]
# Determine the average delays per month, i.e. what month experiences the most delays, it is hypothesized that there will be more subway delays in the winter time because of signal issues due to freezing months and less in the summer months because less people riding

# %%
plt.figure(figsize = (10,5))
ax = sns.lineplot(x =big_df.groupby([big_df['Datetime'].dt.year,"Month"]).sum().groupby("Month").mean()['Count'].index, y= big_df.groupby([big_df['Datetime'].dt.year,"Month"]).sum().groupby("Month").mean()['Count'], color = "grey")
plt.xlabel("Month", fontsize = 14)
plt.ylabel("Average Number of Delays", fontsize = 14)
plt.title("Examining the Average Number of Delays per Month", fontsize = 14, weight = "bold")
plt.savefig("Average Delays by month")

# %% [markdown]
# Why is there peak amount of delays in July and August, but right before the minimum that occurs in June? Typically there is a lack of air conditioning on transit during the summer months, which can cause more heat induced illness during the hotter months.
# https://www.narcity.com/toronto/ttc-commuters-are-so-over-this-summers-heat-and-delays

# %% [markdown]
# What is the probability of experiencing a delay in one month vs the next?

# %%
# determine the average amount of delays per year 
ann_delay_mean = big_df.groupby(big_df['Datetime'].dt.year).sum()['Count'].mean()

# %%
month_prob = big_df.groupby([big_df['Datetime'].dt.year,"Month"]).sum().groupby("Month").mean()['Count']/ann_delay_mean*100

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x =month_prob.index, y = month_prob.values, color = "gray")
plt.ylim([6,10])
plt.xlabel("Month", fontsize = 14)
plt.ylabel("Average Number of Delays", fontsize = 14)
plt.title("Examining the Average Number of Delays per Month", fontsize = 14, weight = "bold")
plt.savefig("Average Delays by month")

# %% [markdown]
# Examine the delay by day of the week: hypothesized that there are more delays during the week than there would be during the weekend

# %% [markdown]
# Examine the delays by hour of the day: hypothesized that there will be a higher amount of delays during rush hour where there are more customers, more likely to cause customer related delays

# %%
# determine the average amount of delays per day 
avg_delays_day = big_df.groupby("Date").sum()['Count'].mean()

# %%
# determine the percent of total delays per day for that hour
average_hourly_delay = big_df.groupby(["Date","Hour"]).sum().groupby("Hour").mean()['Count']/avg_delays_day*100

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x =average_hourly_delay.index, y = average_hourly_delay.values, color = "gray")
plt.ylim([0,10])
plt.xlabel("Hour", fontsize = 14)
plt.ylabel("Percent of Total Delays per Day", fontsize = 14)
plt.title("Examining the Average Number of Delays per hour,\n Most delays occur between 6 am and 5 pm (64%)", fontsize = 14, weight = "bold")
plt.savefig("Percent of delays per hour")

# %%
# what percentage of delays occur between 6 am and 5pm?
average_hourly_delay[6:17].values.sum()
# Out:
# 63.75263503033473

# %% [markdown]
# 64% of delays occur in between 6 am and 5pm (during work hours) depsite taking up less than half the day

# %% [markdown]
# What do delays look like throughout the week? It is expected that there will be a higher amount of delays during the work week since they are more commuters, leading to customer related delays

# %%
# What are the total number of delays per week ?
total_delays_weekly = big_df.groupby(['Date','Day']).sum().groupby("Day").mean()['Count'].sum()

# %%
# What do delays look like on weekdays compared to weekends? where 0 represents monday and 6 represents sunday
dayofweek_delays = big_df.groupby(["Date", "Day"]).sum().groupby("Day").mean()['Count']/total_delays_weekly*100

# %%
plt.figure(figsize = (10,5))
ax = sns.barplot(x =dayofweek_delays.index, y = dayofweek_delays.values, color = "gray")
plt.ylim([0,20])
plt.xlabel("Day of Week (0 Representing Monday)", fontsize = 14)
plt.ylabel("Percent of Total Delays per Week", fontsize = 14)
plt.title("Examining the Percentage of Delays per Day,\n Most delays Occur During Work Days (78%)", fontsize = 14, weight = "bold")
plt.savefig("Percent of delays per day of week")

# %% [markdown]
# It is as expected that most delays (78%) would occur during the week day

# %% [markdown]
# Which stations are experiencing the most delays? It is hypothesized that the the stations that connect lines such as St.George, Spadina, Bloor-Yonge will experience the highest amounts of delays as they are typically the busiest

# %%
big_df.head()
# Out:
#         Date   Time  Day                Station   Code  Min Delay  Min Gap  \
# 0 2014-01-01  00:21    2  VICTORIA PARK STATION  MUPR1         55       60
# 1 2014-01-01  02:06    2      HIGH PARK STATION   SUDP          3        7
# 2 2014-01-01  03:10    2      LANSDOWNE STATION   SUDP          3        8
# 3 2014-01-01  03:20    2          BLOOR STATION  MUSAN          5       10
# 4 2014-01-01  03:29    2       DUFFERIN STATION  MUPAA          0        0
#
#   Bound Line  Vehicle  Code # Vehicle Type  \
# 0     W   BD     5111    52.0          SUB
# 1     W   BD     5001   105.0          SUB
# 2     W   BD     5116   105.0          SUB
# 3     S   YU     5386    53.0          SUB
# 4     E   BD     5174    48.0          SUB
#
#                                     Code Description  \
# 0        PRIORITY ONE - TRAIN IN CONTACT WITH PERSON
# 1                                  DISORDERLY PATRON
# 2                                  DISORDERLY PATRON
# 3                                 UNSANITARY VEHICLE
# 4  PASSENGER ASSISTANCE ALARM ACTIVATED - NO TROU...
#
#                    Datetime  Hour  Count  Month
# 0 2014-01-01 00:21:00-05:00     0      1      1
# 1 2014-01-01 02:06:00-05:00     2      1      1
# 2 2014-01-01 03:10:00-05:00     3      1      1
# 3 2014-01-01 03:20:00-05:00     3      1      1
# 4 2014-01-01 03:29:00-05:00     3      1      1

# %%
big_df['Vehicle Type'].unique()
# Out:
# array(['SUB', 'SRT'], dtype=object)

# %%
big_df[big_df['Station'].str.endswith("STATION")]['S']
# Out:
#              Date   Time  Day                Station   Code  Min Delay  \
# 0      2014-01-01  00:21    2  VICTORIA PARK STATION  MUPR1         55
# 1      2014-01-01  02:06    2      HIGH PARK STATION   SUDP          3
# 2      2014-01-01  03:10    2      LANSDOWNE STATION   SUDP          3
# 3      2014-01-01  03:20    2          BLOOR STATION  MUSAN          5
# 4      2014-01-01  03:29    2       DUFFERIN STATION  MUPAA          0
# ...           ...    ...  ...                    ...    ...        ...
# 140339 2021-06-30  00:47    2       BATHURST STATION   MUIS          0
# 140340 2021-06-30  01:23    2       ST CLAIR STATION   MUIS          0
# 140342 2021-06-30  12:40    2         LESLIE STATION   MUIS          0
# 140343 2021-06-30  20:50    2         LESLIE STATION   MUTD          9
# 140344 2021-06-30  00:45    2         LESLIE STATION  TUMVS          5
#
#         Min Gap Bound Line  Vehicle  Code # Vehicle Type  \
# 0            60     W   BD     5111    52.0          SUB
# 1             7     W   BD     5001   105.0          SUB
# 2             8     W   BD     5116   105.0          SUB
# 3            10     S   YU     5386    53.0          SUB
# 4             0     E   BD     5174    48.0          SUB
# ...         ...   ...  ...      ...     ...          ...
# 140339        0     S   BD        0    43.0          SUB
# 140340        0     S   YU        0    43.0          SUB
# 140342        0     S  SHP        0    43.0          SUB
# 140343       14     E  SHP     6171    55.0          SUB
# 140344       10     E  SHP     6166   119.0          SUB
#
#                                          Code Description  \
# 0             PRIORITY ONE - TRAIN IN CONTACT WITH PERSON
# 1                                       DISORDERLY PATRON
# 2                                       DISORDERLY PATRON
# 3                                      UNSANITARY VEHICLE
# 4       PASSENGER ASSISTANCE ALARM ACTIVATED - NO TROU...
# ...                                                   ...
# 140339  INJURED OR ILL CUSTOMER (IN STATION) - TRANSPO...
# 140340  INJURED OR ILL CUSTOMER (IN STATION) - TRANSPO...
# 140342  INJURED OR ILL CUSTOMER (IN STATION) - TRANSPO...
# 140343                 TRAINING DEPARTMENT RELATED DELAYS
# 140344                           OPERATOR VIOLATED SIGNAL
#
#                         Datetime  Hour  Count  Month
# 0      2014-01-01 00:21:00-05:00     0      1      1
# 1      2014-01-01 02:06:00-05:00     2      1      1
# 2      2014-01-01 03:10:00-05:00     3      1      1
# 3      2014-01-01 03:20:00-05:00     3      1      1
# 4      2014-01-01 03:29:00-05:00     3      1      1
# ...                          ...   ...    ...    ...
# 140339 2021-06-30 00:47:00-04:00     0      1      6
# 140340 2021-06-30 01:23:00-04:00     1      1      6
# 140342 2021-06-30 12:40:00-04:00    12      1      6
# 140343 2021-06-30 20:50:00-04:00    20      1      6
# 140344 2021-06-30 00:45:00-04:00     0      1      6
#
# [128018 rows x 17 columns]

# %%
# load in the shape file for the Toronto area such that the stations can be plotted
neighbourhoods = gpd.read_file('Neighbourhoods.shp')
neighbourhoods.head(5)

# %%
weather_data_2019 = pd.concat([pd.read_csv('Weather_Data/2019/'+filen) for filen in os.listdir('Weather_Data/2019')])
weather_data_2019.head()

# %%
# Set the weather data index to datetime
weather_data_2019.index = pd.DatetimeIndex(weather_data_2019['Date/Time'])
weather_data_2019 = weather_data_2019.drop(['Date/Time'], axis=1)
weather_data_2019.index = weather_data_2019.index.tz_localize(tz='EST')

weather_data_2019.head()
# Out:
#                            Longitude (x)  Latitude (y)         Station Name  \
# Date/Time
# 2019-01-01 00:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-01-01 01:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-01-01 02:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-01-01 03:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
# 2019-01-01 04:00:00-05:00          -79.4         43.63  TORONTO CITY CENTRE
#
#                            Climate ID  Year  Month  Day   Time  Temp (°C)  \
# Date/Time
# 2019-01-01 00:00:00-05:00     6158359  2019      1    1  00:00        4.3
# 2019-01-01 01:00:00-05:00     6158359  2019      1    1  01:00        5.1
# 2019-01-01 02:00:00-05:00     6158359  2019      1    1  02:00        5.9
# 2019-01-01 03:00:00-05:00     6158359  2019      1    1  03:00        3.3
# 2019-01-01 04:00:00-05:00     6158359  2019      1    1  04:00        2.8
#
#                           Temp Flag  ...  Wind Spd Flag Visibility (km)  \
# Date/Time                            ...
# 2019-01-01 00:00:00-05:00       NaN  ...            NaN             4.8
# 2019-01-01 01:00:00-05:00       NaN  ...            NaN            16.1
# 2019-01-01 02:00:00-05:00       NaN  ...            NaN             4.0
# 2019-01-01 03:00:00-05:00       NaN  ...            NaN            16.1
# 2019-01-01 04:00:00-05:00       NaN  ...            NaN            16.1
#
#                            Visibility Flag Stn Press (kPa)  Stn Press Flag  \
# Date/Time
# 2019-01-01 00:00:00-05:00              NaN           98.49             NaN
# 2019-01-01 01:00:00-05:00              NaN           98.47             NaN
# 2019-01-01 02:00:00-05:00              NaN           98.57             NaN
# 2019-01-01 03:00:00-05:00              NaN           98.98             NaN
# 2019-01-01 04:00:00-05:00              NaN           99.29             NaN
#
#                           Hmdx  Hmdx Flag Wind Chill  Wind Chill Flag  \
# Date/Time
# 2019-01-01 00:00:00-05:00  NaN        NaN        NaN              NaN
# 2019-01-01 01:00:00-05:00  NaN        NaN        NaN              NaN
# 2019-01-01 02:00:00-05:00  NaN        NaN        NaN              NaN
# 2019-01-01 03:00:00-05:00  NaN        NaN        NaN              NaN
# 2019-01-01 04:00:00-05:00  NaN        NaN        NaN              NaN
#
#                             Weather
# Date/Time
# 2019-01-01 00:00:00-05:00  Rain,Fog
# 2019-01-01 01:00:00-05:00       NaN
# 2019-01-01 02:00:00-05:00  Rain,Fog
# 2019-01-01 03:00:00-05:00       NaN
# 2019-01-01 04:00:00-05:00       NaN
#
# [5 rows x 27 columns]

# %%
# Write your code here.
plt.figure(figsize=(10, 5))
plt.title('Temperature in the Toronto City Centre for 2019', fontsize=18)
ax = sns.lineplot(data=weather_data_2019, x=weather_data_2019.index, y='Temp (°C)')
ax.set_xlabel('Date-Time', fontsize=18)
ax.set_ylabel('Temperature, °C', fontsize=18)
plt.show()

# %%
delay_df.head()
# Out:
#          Date   Time        Day                Station   Code  Min Delay  \
# 0  2014/01/01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1  2014/01/01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 2  2014/01/01  02:40  Wednesday       SHEPPARD STATION  MUNCA          0
# 3  2014/01/01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4  2014/01/01  03:20  Wednesday          BLOOR STATION  MUSAN          5
#
#    Min Gap Bound Line  Vehicle
# 0       60     W   BD     5111
# 1        7     W   BD     5001
# 2        0   NaN   YU        0
# 3        8     W   BD     5116
# 4       10     S   YU     5386

# %%
delay_df.dtypes
# Out:
# Date         object
# Time         object
# Day          object
# Station      object
# Code         object
# Min Delay     int64
# Min Gap       int64
# Bound        object
# Line         object
# Vehicle       int64
# dtype: object

# %%
#delay_df['dtime'] = pd.to_datetime(delay_df['Date'] + ' ' + delay_df['Time'])

# %%
missing_df = delay_df.isnull().sum().to_frame('count')
missing_df
# Out:
#            count
# Date           0
# Time           0
# Day            0
# Station        0
# Code           1
# Min Delay      0
# Min Gap        0
# Bound      32214
# Line         544
# Vehicle        0

# %%
line = delay_df['Line'].value_counts(normalize=True)
line
# Out:
# YU                        0.463741
# BD                        0.451501
# SRT                       0.037022
# SHP                       0.034114
# YU/BD                     0.011920
#                             ...
# 341 KEELE                 0.000007
# 63 OSSINGTON              0.000007
# 129 MCCOWAN NORTH         0.000007
# YU BD                     0.000007
# YONGE/UNIVERSITY/BLOOR    0.000007
# Name: Line, Length: 71, dtype: float64

# %%
print("Percentage of Accurate Data:\n" ,line.iloc[0:4].sum()*100)
# Out:
# Percentage of Accurate Data:
#  98.63781883618253

# %%
line.index[0:4].values.tolist()
# Out:
# ['YU', 'BD', 'SRT', 'SHP']

# %%
bound = delay_df['Bound'].value_counts()
bound
# Out:
# S    30518
# W    28736
# E    26793
# N    25561
# B       90
# Y        2
# R        1
# 5        1
# 0        1
# Name: Bound, dtype: int64

# %%
bound.index[0:4].values.tolist()
# Out:
# ['S', 'W', 'E', 'N']

# %%
newdf = delay_df.loc[delay_df['Line'].isin(line.index[0:4].values.tolist()) & delay_df['Bound'].isin(bound.index[0:4].values.tolist())]
newdf
# Out:
#               Date   Time        Day                Station   Code  Min Delay  \
# 0       2014/01/01  00:21  Wednesday  VICTORIA PARK STATION  MUPR1         55
# 1       2014/01/01  02:06  Wednesday      HIGH PARK STATION   SUDP          3
# 3       2014/01/01  03:10  Wednesday      LANSDOWNE STATION   SUDP          3
# 4       2014/01/01  03:20  Wednesday          BLOOR STATION  MUSAN          5
# 5       2014/01/01  03:29  Wednesday       DUFFERIN STATION  MUPAA          0
# ...            ...    ...        ...                    ...    ...        ...
# 143908  2021/06/30  00:11  Wednesday            BAY STATION  PUTDN          0
# 143909  2021/06/30  00:42  Wednesday     VAUGHAN MC STATION  MUPAA          0
# 143910  2021/06/30  00:45  Wednesday      OSSINGTON STATION  MUIRS          0
# 143915  2021/06/30  20:50  Wednesday         LESLIE STATION   MUTD          9
# 143916  2021/06/30  00:45  Wednesday         LESLIE STATION  TUMVS          5
#
#         Min Gap Bound Line  Vehicle
# 0            60     W   BD     5111
# 1             7     W   BD     5001
# 3             8     W   BD     5116
# 4            10     S   YU     5386
# 5             0     E   BD     5174
# ...         ...   ...  ...      ...
# 143908        0     W   BD     5112
# 143909        0     S   YU     5511
# 143910        0     E   BD        0
# 143915       14     E  SHP     6171
# 143916       10     E  SHP     6166
#
# [111464 rows x 10 columns]

# %%
newdf['Bound'].value_counts()
# Out:
# S    30492
# W    28684
# E    26746
# N    25542
# Name: Bound, dtype: int64

# %%
newdf.isnull().sum()
# Out:
# Date         0
# Time         0
# Day          0
# Station      0
# Code         1
# Min Delay    0
# Min Gap      0
# Bound        0
# Line         0
# Vehicle      0
# dtype: int64

# %%
newdf.shape
# Out:
# (111464, 10)

# %%
delay_df.shape
# Out:
# (143917, 10)

# %%
newdf.dropna(how='any',inplace=True)

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111463 entries, 0 to 143916
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   Date       111463 non-null  object
#  1   Time       111463 non-null  object
#  2   Day        111463 non-null  object
#  3   Station    111463 non-null  object
#  4   Code       111463 non-null  object
#  5   Min Delay  111463 non-null  int64
#  6   Min Gap    111463 non-null  int64
#  7   Bound      111463 non-null  object
#  8   Line       111463 non-null  object
#  9   Vehicle    111463 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 9.4+ MB

# %%
newdf['Min Delay']
# Out:
# 0         55
# 1          3
# 3          3
# 4          5
# 5          0
#           ..
# 143908     0
# 143909     0
# 143910     0
# 143915     9
# 143916     5
# Name: Min Delay, Length: 111463, dtype: int64

# %%
df_100delay=newdf.sort_values('Min Delay', ascending=False).head(100)

# %%
plt.figure(figsize=(12, 12))
plt.legend(fontsize=10)
plt.tick_params(labelsize=10)
ax=sns.scatterplot(x=df_100delay['Code'],y=df_100delay['Station'],hue=df_100delay['Line'],size=df_100delay['Min Delay'],data=df_100delay,sizes=(50,500))
plt.setp(ax.get_xticklabels(), rotation=90)
ax.legend(loc='upper left',bbox_to_anchor=(1,1))
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
newdf.groupby('Day')['Code'].count().plot.bar(figsize=(10,10))
plt.show()

# %%
newdf.groupby('Code')['Code'].count().sort_values(ascending=False).head(50).plot.bar(figsize=(20,10))
plt.show()

# %%
#plt.figure(figsize=(20, 6))
newdf.groupby(newdf['Day'])['Min Delay'].agg(['mean']).plot.bar()
plt.show()

# %%
code_df.loc[code_df['RMENU CODE'] == 'MUSC']['CODE DESCRIPTION']
# Out:
# 53    Miscellaneous Speed Control
# Name: CODE DESCRIPTION, dtype: object

# %%
df_100delay.groupby('Code')['Code'].count().sort_values(ascending=False).head(50).plot.bar(figsize=(20,10))
plt.show()

# %%
df_100delay.groupby('Code')['Code'].count().sort_values(ascending=False).index[0]
# Out:
# 'MUPR1'

# %%
code_df.loc[code_df['RMENU CODE'] == 'MUPR1']['CODE DESCRIPTION']
# Out:
# 51    Priority One - Train in Contact With Person
# Name: CODE DESCRIPTION, dtype: object
